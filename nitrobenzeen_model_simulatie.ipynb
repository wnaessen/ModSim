# %% [markdown]
# ## Model simuleren: nitrobenzeenmodel

# %% [markdown]
# $$\frac{d[C6H6]}{dt}= -2k{[C6H6]}^2[N2O5] + \frac{Q}{V}({[C6H6]}_{in} - [C6H6])$$
# $$\frac{d[N2O5]}{dt}= -k{[C6H6]}^2[N2O5] + \frac{Q}{V}({[N2O5]}_{in} - [N2O5])$$
# $$\frac{d[C6H5NO2]}{dt}= 2k{[C6H6]}^2[N2O5] - \frac{Q}{V}[C6H5NO2] $$

# %%
# %matplotlib inline

# %%
# Importeren van functionaliteiten
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import scipy as sp
import pandas as pd
from IPython.display import Image
from ipywidgets import interact, fixed
# %load_ext autoreload
# %autoreload 1
# %aimport nitrobenzeen
#from populatie import populatie_model   # Importeren van de populatie functies
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# #### Praktische info
# functiedefinitie:
#
#     nitrobenzeen_model(tijdstappen, C6H6_0, N2O5_0, C6H5NO2_0, k, Q, V, C6H6_in, N2O5_in)
#
# Bij de standaard situatie voor onze case werden volgende waarden voor initiele condities, parameters en inputs gebruikt:
#
#     nitrobenzeen_model(np.arange(0, 1500, 1), 0.03, 0, 0, 2, 10, 3000, 0, 0.03)

# %% [markdown]
# ## Model simuleren

# %% [markdown]
# ## impact initiele conditie

# %%
interact(nitrobenzeen.nitrobenzeen_model, tijdstappen=fixed(np.arange(0., 1500, 1)), C6H6_0=(0., 1., 0.01), N2O5_0=(0., 1., 0.01), C6H5NO2_0=(0., 1., 0.01), k=fixed(2),Q=fixed(10), V=fixed(3000), C6H6_in=fixed(0), N2O5_in=fixed(0.03),returnDataFrame=fixed(False));

# %% [markdown]
# $$\frac{d[C6H6]}{dt}= -2k{[C6H6]}^2[N2O5] + \frac{Q}{V}({[C6H6]}_{in} - [C6H6])$$
# $$\frac{d[N2O5]}{dt}= -k{[C6H6]}^2[N2O5] + \frac{Q}{V}({[N2O5]}_{in} - [N2O5])$$
# $$\frac{d[C6H5NO2]}{dt}= 2k{[C6H6]}^2[N2O5] - \frac{Q}{V}[C6H5NO2] $$

# %% [markdown]
# ## impact inputs

# %%
interact(nitrobenzeen.nitrobenzeen_model, tijdstappen=fixed(np.arange(0., 1500, 1)), C6H6_0=fixed(0.03), N2O5_0=fixed(0), C6H5NO2_0=fixed(0), k=fixed(2),Q=fixed(10), V=fixed(3000), C6H6_in=(0,1,0.01), N2O5_in=(0,0.1,0.01),returnDataFrame=fixed(False));

# %% [markdown]
# $$\frac{d[C6H6]}{dt}= -2k{[C6H6]}^2[N2O5] + \frac{Q}{V}({[C6H6]}_{in} - [C6H6])$$
# $$\frac{d[N2O5]}{dt}= -k{[C6H6]}^2[N2O5] + \frac{Q}{V}({[N2O5]}_{in} - [N2O5])$$
# $$\frac{d[C6H5NO2]}{dt}= 2k{[C6H6]}^2[N2O5] - \frac{Q}{V}[C6H5NO2] $$

# %% [markdown]
# ## impact parameters

# %%
interact(nitrobenzeen.nitrobenzeen_model, tijdstappen=fixed(np.arange(0., 1500, 1)), C6H6_0=fixed(0.03), N2O5_0=fixed(0), C6H5NO2_0=fixed(0), k=(0.,10.,0.1),Q=(0., 20., 1.), V=(0.,6000.,100.), C6H6_in=fixed(0), N2O5_in=fixed(0.03),returnDataFrame=fixed(False));

# %% [markdown]
# $$\frac{d[C6H6]}{dt}= -2k{[C6H6]}^2[N2O5] + \frac{Q}{V}({[C6H6]}_{in} - [C6H6])$$
# $$\frac{d[N2O5]}{dt}= -k{[C6H6]}^2[N2O5] + \frac{Q}{V}({[N2O5]}_{in} - [N2O5])$$
# $$\frac{d[C6H5NO2]}{dt}= 2k{[C6H6]}^2[N2O5] - \frac{Q}{V}[C6H5NO2] $$
